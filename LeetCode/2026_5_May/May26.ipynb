# %% [markdown]
# MAY 26, 2026
# Count the Number of Special Characters

# %%
word = 'Amazing'

# %%
def numberOfSpecialChars(word):
        lower_chars = set()
        upper_chars = set()

        for ch in word:
            if ch.islower():
                  lower_chars.add(ch)
            elif ch.isupper():
                  upper_chars.add(ch.lower())
        
        print(lower_chars & upper_chars)
        return len(lower_chars & upper_chars)

word = "AbsolutelyAmazingIDontKnowHowYouDoit"
print(numberOfSpecialChars(word))
# Out:
# {'i', 'y', 'a'}
# 3

# %% [markdown]
# May 27, 2026
# #3121 Count the Number of Special Characters

# %%
class Solution(object):
    def numberOfSpecialChars(self, word):
        #First uppercase
        first = {}
        # The last lowercase
        last = {}

        for i, c in enumerate(word):
            if c.isupper():
                c = c.lower()
                if c not in first:
                    first[c] = i
            else:
                last[c] = i

        count = 0
        for c in string.ascii_lowercase:
            if c in first and c in last and last[c] < first[c]:
                count += 1

        return count

# %%
def numberOfSpecialChars(word):
    lower_chars = set()
    count = 0
    i = 0
    for ch in word:
        if ch.islower():
              first_ch_upper = ch.upper()
              index = word.find(first_ch_upper)
              if i < index and ch not in lower_chars:
                count += 1   
              lower_chars.add(ch)  
        i += 1
    return count

word = "aaAbcBC"
print(numberOfSpecialChars(word))
# Out:
# 3

# %%
s = "AbBCab"

lowercase_positions = [i for i, ch in enumerate(s) if ch.islower()]
print(lowercase_positions)

uppercase_positions = [i for i, ch in enumerate(s) if ch.isupper()]
print(uppercase_positions)
# Out:
# [1, 4, 5]
# [0, 2, 3]

# %%
for i in s:
    largest_index_for_letter = max()

# %%
import string

def numberofSpecialChars(word):
    #First uppercase
    first = {}
    # The last lowercase
    last = {}

    for i, c in enumerate(word):
        if c.isupper():
            c = c.lower()
            if c not in first:
                first[c] = i
        else:
            last[c] = i

    count = 0
    for c in string.ascii_lowercase:
        if c in first and c in last and last[c] < first[c]:
            count += 1

    return count

# %%
word = "aAbbB"

lowercase_positions = [i for i, ch in enumerate(s) if ch.islower()]
print(lowercase_positions)

uppercase_positions = [i for i, ch in enumerate(s) if ch.isupper()]
print(uppercase_positions)

print(numberofSpecialChars(word))
# Out:
# [1, 4, 5]
# [0, 2, 3]
# 2
